# %% [markdown]
# <a href="https://colab.research.google.com/github/antonysama/PreSumm/blob/master/pyrouge_install_oct6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation of pyrouge on Google Colab

# %%
# %cd "My Drive"
# Out:
# /content/drive/My Drive

# %%
# !mkdir my_pyrouge2

# %%
# install missing dependency
# !apt install libxml-parser-perl
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libxml-parser-perl is already the newest version (2.44-2build3).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating pyrouge.egg-info
# writing pyrouge.egg-info/PKG-INFO
# writing dependency_links to pyrouge.egg-info/dependency_links.txt
# writing top-level names to pyrouge.egg-info/top_level.txt
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pyrouge
# copying pyrouge/Rouge155.py -> build/lib/pyrouge
# copying pyrouge/__init__.py -> build/lib/pyrouge
# copying pyrouge/test.py -> build/lib/pyrouge
# creating build/lib/pyrouge/utils
# copying pyrouge/utils/__init__.py -> build/lib/pyrouge/utils
# copying pyrouge/utils/argparsers.py -> build/lib/pyrouge/utils
# copying pyrouge/utils/file_utils.py -> build/lib/pyrouge/utils
# copying pyrouge/utils/log.py -> build/lib/pyrouge/utils
# ...

# %%
#separate each line
# install bheinzerling's pyrouge
#!mkdir my_pyrouge2
#cd my_pyrouge2
#!git clone https://github.com/bheinzerling/pyrouge
#cd pyrouge
#!python setup.py install

# %%
# get adersjo's pyrouge tools
# %%bash
cd my_pyrouge/pyrouge
git clone https://github.com/andersjo/pyrouge.git rouge
# Out:
# bash: line 1: cd: my_pyrouge/pyrouge: No such file or directory
# Cloning into 'rouge'...
# Checking out files: 100% (355/355), done.

# %%
# !pwd
# Out:
# /content/drive/My Drive/my_pyrouge2/pyrouge

# %%
# build db file and run test
# %%bash
DIR="/content/drive/My Drive/my_pyrouge2/pyrouge/rouge/tools/ROUGE-1.5.5"
pyrouge_set_rouge_path $DIR
cd $DIR/data
mv WordNet-2.0.exc.db WordNet-2.0.exc.db.orig
perl WordNet-2.0-Exceptions/buildExeptionDB.pl ./WordNet-2.0-Exceptions ./smart_common_words.txt ./WordNet-2.0.exc.db
python -m pyrouge.test
# Out:
# /tmp/tmpm8y1z3ai/config_test.xml data/config_test.xml
# usage: pyrouge_set_rouge_path [-h] home_dir
# pyrouge_set_rouge_path: error: unrecognized arguments: Drive/my_pyrouge2/pyrouge/rouge/tools/ROUGE-1.5.5
# bash: line 3: cd: too many arguments
# mv: cannot stat 'WordNet-2.0.exc.db': No such file or directory
# Can't open perl script "WordNet-2.0-Exceptions/buildExeptionDB.pl": No such file or directory
# 2019-10-07 04:49:47,749 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmp87mpny4n/rouge_conf.xml
# .2019-10-07 04:49:48,041 [MainThread  ] [INFO ]  Processing files in data/SL2003_models_plain_text.
# 2019-10-07 04:49:48,042 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-01.html.
# 2019-10-07 04:49:48,043 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-02.html.
# 2019-10-07 04:49:48,044 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-03.html.
# 2019-10-07 04:49:48,045 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-04.html.
# ...
